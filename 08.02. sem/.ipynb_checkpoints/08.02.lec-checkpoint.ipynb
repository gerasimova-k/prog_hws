# %%
#например, токенизация. нет готовых инструментов. не хочется копировать, надо в неск проектах => отдельный py скрипт. нет выполняемого кода, только определение ф-ции
#импортов много.

import #оператор
import math #питон ищет модуль с таким именем, сначала ищет в домашнем каталоге. если был бы скрипт math.py - он бы импортировал оттуда. дальше - каталоги стандартной библиотеки
#дальше импортирует пространство имен, можно получать содержимое только с пом спец синтаксиса
#math.sqrt(4) - иначе скврт не откроется
# pandas - не стандартная библиотека, не найдет так
#командная строка, !pip install pandas - установка в команде
#анаконда - сервис, работает с библиотеками питона. dependency - зависят друг от друга. numpy - нужен pandas
#! pip git - установка напрямую с гита
# три вида - встроенные (модуль примерно равно библиотека). есть pip install - установка через инет. третье - самописные модули
from math import
import pandas as pd
#dir(math) - с нижним стандартное, без - спец ф-ции, можно посмотреть содержание
#help(math.tan) - выводит описание команды
def tan(x):
  '''tan(x, /)
  retrurn the tan of x - это докстринг''' 

def hello():
  print('hello')

#так мы положим создадим скрипт с расширением .py, сохраним на компе, дальше import hello, можно будет ее вызвать

#классы и ООП
#последовательно типа циклы - структурная парадигма. без ф-ций - слишком много копипейст.
#ооп - пишем в классах, абстрагирование кода. онтологии- ООП
#цели: больший порядок.

def read(path"""абстракция уже"""):
  #код собирается в ООП в куски абстракций

print('hello') #строка = класс, т.е объект
#многие библиотеки написаны в классах
#объект и метод - подлежащее и предикат положим
#тип = класс в питоне
#типы данных = класс
object #самый общий, entity - максимально абстрактный объект программного мира
#есть представители, экземпляры
#наследование - от класса человек идет класс студент, то же самое все умеет условно
#встроенные классы - int, float, string ...
#custom class - свои классы.
#названия классов с большой буквы
#атрибуты и методы
#атрибуты всего класса. положим, у всех людей 2 глаза
class Human:  #MyClass
  eyes = 2 #задана переменная внутри класса
  def 

class Human:  #MyClass
  eyes = 2 #задана переменная внутри класса, статический элемент
 # def __init__(self, * """передача по ключу""", name, age: int):
  def __init__(self, name, age): #self - абстрактно отсылает к экземпляру
    self.name = name
    self.age = age
  def __str__(self):
    return f'{self.name}: {self.age}'
  def __repr__(self): #representation без принта
    return f'Human("{self.name}", {self.age})'
    #eval превращ строку в код обратно
#  def showage(self, other """другой экземпляр""" ):
  def showage(self, other):
    x = self.age % 10
    xx = self.age % 100
    years = 'лет'
    if 11 < xx < 16:
      if x == 1:
        years = 'год' 
      elif x in {2, 3, 4}:
        years = 'года'
    print(f'{self.name}: возраст{self.age} {years}')
  def compare(self, other):
    return True if self.age > other.age else False #тернарный оператор
  
  def mymethod():
    print()

h = Human('Vasya', 18)
v = Human("Petta", 20)

#есть статические методы - к клкассу. dict.fromkeys()

[v, h] #вот так красиво вывежено благодаря репр
print(v)

#принт неявно все преобразует в строки. как объект класса превратитть в строку - через обджект. <__main__.Human object at 0x7f75dfc61190> - поэтому
#он так выглядит эта команда print(h)

print(h)

h = Human() #когда заведен конкр экз - у него конкр хар-ки, напр имя разное, цвет волос. приписать экз хар-ки можно:

h = Human('Vasya') #Human.__init__(h, 'Vasya')

h = Human('Vasya', 18) #h = self

h.age

h.eyes = 1

h.eyes

h.name = 'Vasya'
#у др объектов класса имен нет

h.name

v = Human()

v.name

#почему у типа объекта есть маг метод такого же назв

#при созд класса каж экз приписываем имя - для этого переопределяем магич метод (не выз явно)

#магические методы - не замечаем как вызываются. у human есть наследованные от класса object хар-ки

import antigravity
