# %%
from gtts import gTTS
user_lang = input('Введите язык латинскими буквами').lower()
user_txt = input('Введите текст')
tts = gTTS(text = user_txt, lang = user_lang[0:2])
tts.save('user_audio.mp3')
# Out:
# Введите язык латинскими буквами russian
# Введите текст Под этим подразумевается использование цифрового метода нанесения изображения на носитель. Он позволяет получать любые сочетания оттенков с точной передачей полутонов и теней, благодаря чему считается быстрым и надёжным способом получения полиграфической продукции.

# %%
from playsound import playsound

# %%
from pydub import AudioSegment

# %%
src = r"C:\Users\Кристина\python 2 курс\29.09.2023\Iofan.mp3"
dst = r"C:\Users\Кристина\python 2 курс\29.09.2023\Iofan.wav"

# mp3 => wav                                                           
sound = AudioSegment.from_mp3(src)
sound.export(dst, format="wav")
# Out:
# <_io.BufferedRandom name='C:\\Users\\Кристина\\python 2 курс\\29.09.2023\\Iofan.wav'>

# %%
from pympi import Elan

# %%
doc = Elan.Eaf(file_path= r"C:\Users\Кристина\python 2 курс\29.09.2023\RSLM-cr1-s14-a15.eaf.txt") # открываем файл

# %%
tiers = doc.get_tier_names()

# %%
tiers
# Out:
# dict_keys(['ЛР глосс', 'ПР глосс', 'предложения', 'комментарии'])

# %%
doc.tiers
# Out:
# {'ЛР глосс': ({'a7': ('ts1', 'ts4', 'дом:PL', None),
#    'a8': ('ts7', 'ts10', 'табличка', None),
#    'a9': ('ts16', 'ts30', 'общество', None),
#    'a10': ('ts33', 'ts38', 'смотреть.бинокль', None),
#    'a11': ('ts40', 'ts42', 'окно', None),
#    'a12': ('ts44', 'ts48', 'подоконник', None),
#    'a13': ('ts51', 'ts54', 'уши', None),
#    'a14': ('ts55', 'ts58', 'смотреть.в.бинокль', None),
#    'a15': ('ts60', 'ts64', 'уши', None),
#    'a16': ('ts66', 'ts74', 'смотреть.бинокль', None),
#    'a17': ('ts76', 'ts80', 'кот', None),
#    'a18': ('ts81', 'ts88', 'смотреть.бинокль', None),
#    'a19': ('ts89', 'ts92', 'дом', None),
#    'a20': ('ts93', 'ts98', 'напротив', None),
#    'a21': ('ts99', 'ts104', 'бинокль', None),
#    'a22': ('ts114', 'ts122', 'смотреть.бинокль', None),
#    'a23': ('ts127', 'ts136', 'клетка', None),
#    'a24': ('ts138', 'ts140', 'голова', None),
#    'a25': ('ts143', 'ts146', 'жёлтый', None),
#    'a26': ('ts157', 'ts159', 'так.же', None),
# ...

# %%
doc.linguistic_types
# Out:
# {'default-lt': {'GRAPHIC_REFERENCES': 'false',
#   'LINGUISTIC_TYPE_ID': 'default-lt',
#   'TIME_ALIGNABLE': 'true'}}

# %%
doc.languages
# Out:
# {}

# %%
doc.timeslots
# Out:
# {'ts1': 570,
#  'ts2': 570,
#  'ts3': 570,
#  'ts4': 2790,
#  'ts5': 2790,
#  'ts6': 2790,
#  'ts7': 3390,
#  'ts8': 3390,
#  'ts9': 3390,
#  'ts10': 4660,
#  'ts11': 4660,
#  'ts12': 4660,
#  'ts13': 4660,
#  'ts14': 4660,
#  'ts15': 5510,
#  'ts16': 5510,
#  'ts17': 5510,
#  'ts18': 5510,
#  'ts19': 5510,
#  'ts20': 6380,
#  'ts21': 6380,
#  'ts22': 7240,
#  'ts23': 7240,
#  'ts24': 7590,
#  'ts25': 7590,
#  'ts26': 8600,
#  'ts27': 8610,
#  'ts28': 8610,
#  'ts29': 8610,
#  'ts30': 10260,
#  'ts31': 10260,
#  'ts32': 10260,
#  'ts33': 10268,
#  'ts34': 10268,
#  'ts35': 10268,
#  'ts36': 11450,
#  'ts37': 11450,
#  'ts38': 11458,
#  'ts39': 11458,
#  'ts40': 11458,
#  'ts41': 11458,
#  'ts42': 11688,
#  'ts43': 11688,
#  'ts44': 11688,
#  'ts45': 11688,
#  'ts46': 12748,
#  'ts47': 12748,
#  'ts48': 13348,
#  'ts49': 13348,
#  'ts50': 13348,
#  'ts51': 13348,
#  'ts52': 13950,
#  'ts53': 13958,
#  'ts54': 13958,
#  'ts55': 13958,
#  'ts56': 13958,
#  'ts57': 13958,
# ...

# %%
import textgrids

# %%
grid = textgrids.TextGrid(r"pears.TextGrid")

# %%
grid['C-lines'][:2]
# Out:
# [<Interval text="pC-001" xmin=0.0 xmax=219.74375>,
#  <Interval text="C-vN001" xmin=219.74375 xmax=219.91762>]

# %%
print(textgrids.vowels)
# Out:
# ['a', 'e', 'i', 'o', 'u', 'y', 'æ', 'ø', '\\i-', '\\u-', '\\mt', '\\ic', '\\yc', '\\hs', '\\o/', '\\e-', '\\o-', '\\rh', '\\sw', '\\ef', '\\oe', '\\er', '\\kb', '\\vt', '\\ct', '\\ae', '\\at', '\\Oe', '\\as', '\\ab', 'ɨ', 'ʉ', 'ɯ', 'ɪ', 'ʏ', 'ʊ', 'ø', 'ɘ', 'ɵ', 'ɤ', 'ə', 'ɛ', 'œ', 'ɜ', 'ɞ', 'ʌ', 'ɔ', 'æ', 'ɐ', 'ɶ', 'ɑ', 'ɒ']
