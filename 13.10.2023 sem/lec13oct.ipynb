# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fig.set(facecolor='green')
ax.set(facecolor='blue')
plt.show()

# %%
X = ['a', 'b', 'c', 'd']
Y = [34, 123, 67, 45]
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(X, Y, 'bo')
plt.show()

# %%
plt.plot(X, Y, '^g')
plt.show()

# %%
ax_1 = fig.add_subplot(2, 2, 1)
ax_2 = fig.add_subplot(2, 2, 2)
ax_3 = fig.add_subplot(2, 2, 3)
ax_4 = fig.add_subplot(2, 2, 4)

# %%
fig, axes = plt.subplots(nrows = 2, ncols =2 )

axes[0,0].set(title='axes[0,0]')
axes[0,1].set(title='axes[0,1]')
axes[1,0].set(title='axes[1,0]')
axes[1,1].set(title='axes[1,1]')

for ax in axes.flat:
    ax.set(...)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       6 axes[1,1].set(title='axes[1,1]')
#       8 for ax in axes.flat:
# ----> 9     ax.set(...)
#      11 plt.show()
#
# TypeError: <lambda>() takes 1 positional argument but 2 were given

# %%
fig, ax = plt.subplots()

# %%
from mpl_toolkits.mplot3d import axes3d

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
X, Y, Z = [1, 2, 7, 3, 6], [7, 3, 2, 5, 2], [1, 9, 7, 3, 6]
ax.plot(X, Y, Z)
plt.show()

# %%
import seaborn as sns

# %%
palette = sns.color_palette("br")  # напечатать какую-нибудь ерунду вместо названия палитры, и в ошибке сиборн послушно вывалит все свои пали
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\palettes.py:235, in color_palette(palette, n_colors, desat, as_cmap)
#     233 try:
#     234     # Perhaps a named matplotlib colormap?
# --> 235     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236 except (ValueError, KeyError):  # Error class changed in mpl36
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\palettes.py:406, in mpl_palette(name, n_colors, as_cmap)
#     405 else:
# --> 406     cmap = get_colormap(name)
#     408 if name in MPL_QUAL_PALS:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_compat.py:133, in get_colormap(name)
#     132 try:
# --> 133     return mpl.colormaps[name]
#     134 except AttributeError:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\cm.py:88, in ColormapRegistry.__getitem__(self, item)
#      87 except KeyError:
# ---> 88     raise KeyError(f"{item!r} is not a known colormap name") from None
#
# KeyError: "'br' is not a known colormap name"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 import seaborn as sns
# ----> 3 palette = sns.color_palette("br")  # напечатать какую-нибудь ерунду вместо названия палитры, и в ошибке сиборн послушно вывалит все свои пали
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\palettes.py:237, in color_palette(palette, n_colors, desat, as_cmap)
#     235             palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236         except (ValueError, KeyError):  # Error class changed in mpl36
# --> 237             raise ValueError(f"{palette!r} is not a valid palette name")
#     239 if desat is not None:
#     240     palette = [desaturate(c, desat) for c in palette]
#
# ValueError: 'br' is not a valid palette name

# %%
sns.set_context('paper', 'notebook', 'talk', 'poster')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.set_context('paper', 'notebook', 'talk', 'poster')
#
# TypeError: set_context() takes from 0 to 3 positional arguments but 4 were given

# %%
palette = sns.color_palette('gist_earth_r')
sns.palplot(palette)

# %%
from ipywidgets import IntProgress
from IPython.display import display
import time

max_count = 100

f = IntProgress(min=0, max=max_count) # создаем экземпляр класса
display(f) # отображаем наш экземпляр

for i in range(100):
    f.value += 1 # signal to increment the progress bar
    time.sleep(.1)
# Out:
# IntProgress(value=0)

# %%
from random import randrange
def myfunc(x, n):
    x = [randrange(0, x + 1) for i in range(n)]
    y = [i ** 2 for i in x]
    sns.barplot(x=x, y=y, color='lime', errorbar=None)
    plt.show()

# %%
from ipywidgets import interact, IntSlider

interact(myfunc, x=IntSlider(min=1, max=30, step=1, value=1), n=list(range(1, 11)))
# Out:
# interactive(children=(IntSlider(value=1, description='x', max=30, min=1), Dropdown(description='n', options=(1…
# <function __main__.myfunc(x, n)>
